# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key='AIzaSyBr-YBSKSwOAZH1KrYj16Z1qrMhZ76FjG0'

# %%
channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
api_service_name="youtube"
api_version="v3"

youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data=[]

    request = youtube.channels().list(
        part="snippet,contentDetails, statistics",
        id=",".join(channel_ids)
    )
    response = request.execute()

    # JSON(response)
    
    #loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalViews': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
                
               }
        all_data.append(data)
    
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers      views totalViews                playlistId
# 0  Ali Abdaal     3000000  200158947        448  UUoOae5nYA7VqaXzerajD0lg

# %%
playlist_id = "UUoOae5nYA7VqaXzerajD0lg"

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    

    request = youtube.playlistItems().list(
        part = "snippet, contentDetails",
        playlistId = "UUoOae5nYA7VqaXzerajD0lg",
        maxResults = 50
    )
    response = request.execute()

    # JSON(response)
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
        
    while next_page_token is not None:
            
        request = youtube.playlistItems().list(
            part = "snippet, contentDetails",
            playlistId = "UUoOae5nYA7VqaXzerajD0lg",
            maxResults = 50,
            pageToken = next_page_token
        )
        response = request.execute()

        # JSON(response)
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
            
        next_page_token = response.get('nextPageToken')
            
   
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 448

# %%
def get_video_details(youtube, video_ids):
    all_video_info=[]

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet, contentDetails, statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

    for video in response['items']:
        stats_to_keep = {'snippets': ['channelTitle', 'title', 'description', 'tags','publishedAt'],
                         'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                         'contentDetails': ['duration','defination','caption']
                        }
        video_info = {}
        video_info['video_id'] = video['id']
    
        for k in stats_to_keep.keys():
            for v in stats_to_keep[k]:
                try:
                    video_info[v] = video[k][v]
                except:
                    video_info[v] = None
                    
        all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#        video_id channelTitle title description  tags publishedAt viewCount  \
# 0   iIdqPeI-Po0         None  None        None  None        None     28353
# 1   1lMCGdVAgGQ         None  None        None  None        None    256771
# 2   heN8Zo8f45I         None  None        None  None        None     28091
# 3   uY01uhhIuzI         None  None        None  None        None     68480
# 4   AuORG4zFcXw         None  None        None  None        None     67681
# 5   ecKHOHmPq1g         None  None        None  None        None     12572
# 6   vMJKprNmEEg         None  None        None  None        None      8112
# 7   UJmz89F_bqA         None  None        None  None        None     41030
# 8   Q6fwLEO3G3Q         None  None        None  None        None     13309
# 9   1wLNDHVQxU4         None  None        None  None        None      9845
# 10  QxXwfMrWYPE         None  None        None  None        None     10424
# 11  -6YiD77uWD8         None  None        None  None        None     13742
# 12  U31WDm6RNYc         None  None        None  None        None     22595
# 13  MpevcHafHZI         None  None        None  None        None     46840
# 14  GT9ZQX1OS68         None  None        None  None        None     54633
# 15  oHjMygB8y4k         None  None        None  None        None      5006
# 16  wiuEDpZGAw8         None  None        None  None        None      3770
# 17  sDFe-OJmVXc         None  None        None  None        None      6381
# 18  OQs0fYHPzho         None  None        None  None        None      2146
# 19  nTookJPZiTU         None  None        None  None        None      2837
# 20  g4ukmp-hn8Y         None  None        None  None        None      7166
# 21  UI2fzaXO78E         None  None        None  None        None     24354
# 22  nx8wnXdEYG8         None  None        None  None        None      2754
# 23  -dw8fYgBK1I         None  None        None  None        None      6078
# 24  tJDgQv_W15s         None  None        None  None        None      5667
# 25  Bmxjb3qThWI         None  None        None  None        None     14137
# 26  W5L9oZN9LeM         None  None        None  None        None      4404
# 27  Xk0e6XZUyrQ         None  None        None  None        None     18027
# 28  MhUljoWSzSk         None  None        None  None        None      6395
# 29  8LOB92gjgww         None  None        None  None        None     17500
# 30  c5o1I7S7_Iw         None  None        None  None        None     15278
# 31  f_3IrUKQAQ8         None  None        None  None        None     23310
# 32  z2xKvVNZgL0         None  None        None  None        None      9621
# 33  e4yXab6Zc9A         None  None        None  None        None     26152
# 34  rs2BRk-RMJA         None  None        None  None        None     16169
# 35  VRaUyEY4Pnc         None  None        None  None        None     16560
# 36  XcZnSSmeK2I         None  None        None  None        None     31792
# 37  HGTzYlkT5Ww         None  None        None  None        None     40841
# 38  fVkc5hr_FhA         None  None        None  None        None    145863
# 39  vdmg-KAx9yE         None  None        None  None        None      9908
# 40  34ehGQMt5l4         None  None        None  None        None      7346
# 41  AAnIrWVVFsM         None  None        None  None        None      9197
# 42  FEUIxnnW5-w         None  None        None  None        None     15368
# 43  7APfFjfnNBc         None  None        None  None        None     70793
# 44  gBpBLTSCb4s         None  None        None  None        None     12609
# 45  Va0tSdPADpA         None  None        None  None        None     31838
# 46  XJHM0fEH3ss         None  None        None  None        None     43585
# 47  LQ3Mu8A7gjY         None  None        None  None        None     88405
#
#    likeCount favouriteCount commentCount  duration defination caption
# 0        678           None           29  PT12M19S       None   false
# 1       6848           None          198  PT12M52S       None   false
# 2        642           None           24   PT2M45S       None   false
# 3       2306           None           48  PT13M22S       None   false
# 4       1590           None          113    PT9M4S       None   false
# 5        392           None           14   PT5M14S       None   false
# 6        262           None            7   PT3M48S       None   false
# 7       1683           None           28  PT10M17S       None   false
# 8        330           None            8   PT3M51S       None   false
# 9        249           None            4   PT4M12S       None   false
# 10       253           None            6   PT2M58S       None   false
# 11       321           None            8   PT5M31S       None   false
# 12       579           None           15   PT7M33S       None   false
# 13      1063           None           27   PT3M19S       None   false
# 14      1500           None          146   PT15M1S       None   false
# 15       142           None            7   PT5M56S       None   false
# 16       109           None            5   PT4M17S       None   false
# 17       160           None           10   PT7M21S       None   false
# 18        77           None            6    PT4M4S       None   false
# 19        94           None            5   PT5M11S       None   false
# 20       156           None           11   PT3M25S       None   false
# 21       564           None           20   PT8M31S       None   false
# 22       110           None            4    PT3M4S       None   false
# 23       123           None            9   PT3M24S       None   false
# 24       148           None            5      PT2M       None   false
# 25       436           None           14   PT5M15S       None   false
# 26       145           None            9   PT3M16S       None   false
# 27       475           None           16   PT4M46S       None   false
# 28        85           None            2   PT4M14S       None   false
# 29       257           None            7   PT3M56S       None   false
# 30       320           None           23   PT4M45S       None   false
# 31       503           None           10   PT5M34S       None   false
# 32       277           None           16   PT4M46S       None   false
# 33       830           None           85   PT3M45S       None   false
# 34       260           None            9   PT3M33S       None   false
# 35       311           None            9   PT2M39S       None   false
# 36       627           None           25   PT4M48S       None   false
# 37       777           None           39   PT4M16S       None   false
# 38      2801           None          105   PT5M48S       None   false
# 39       225           None           11   PT3M41S       None   false
# 40       142           None           13    PT3M9S       None   false
# 41       127           None            7   PT3M13S       None   false
# 42       224           None           14   PT3M33S       None   false
# 43      1855           None          109   PT2M35S       None   false
# 44        91           None            4   PT2M11S       None   false
# 45       240           None            8   PT2M18S       None   false
# 46       550           None           28   PT2M29S       None   false
# 47      1116           None          115   PT1M43S       None   false

# %%
# Data Pre processing

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle       True
# title              True
# description        True
# tags               True
# publishedAt        True
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# defination         True
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# defination        object
# caption           object
# dtype: object
